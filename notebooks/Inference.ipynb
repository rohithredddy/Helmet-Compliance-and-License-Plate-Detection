# %%
from src.inference import HelmetInference

model_path = "results/weights/best.pt"

infer = HelmetInference(model_path)

# Single image
img = infer.detect_image("real imgs/day_18.jpeg")

# Folder inference + save
infer.detect_folder(
    folder_path="Inference Data/Night Images",
    output_dir="Inference results/night_outputs",
    conf_threshold=0.25
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.inference import HelmetInference
#       3 model_path = "results/weights/best.pt"
#       5 infer = HelmetInference(model_path)
#
# ModuleNotFoundError: No module named 'src'
